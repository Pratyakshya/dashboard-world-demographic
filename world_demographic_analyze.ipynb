# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyakshya/dashboard-world-demographic/blob/main/world_demographic_analyze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/wdi_wide.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country Name                  217 non-null    object
#  1   Region                        216 non-null    object
#  2   Subregion                     216 non-null    object
#  3   Intermediate Region           216 non-null    object
#  4   GNI                           207 non-null    float64
#  5   Internet use                  213 non-null    float64
#  6   International tourism         203 non-null    float64
#  7   Life expectancy, female       208 non-null    float64
#  8   Life expectancy, male         208 non-null    float64
#  9   Physicians                    207 non-null    float64
#  10  Population                    217 non-null    float64
#  11  Women in national parliament  193 non-null    float64
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of               Country Name  ... High Income Economy
# 0              Afghanistan  ...                  No
# 1                  Albania  ...                  No
# 2                  Algeria  ...                  No
# 3           American Samoa  ...                  No
# 4                  Andorra  ...                  No
# ..                     ...  ...                 ...
# 212  Virgin Islands (U.S.)  ...                  No
# 213     West Bank and Gaza  ...                  No
# 214            Yemen, Rep.  ...                  No
# 215                 Zambia  ...                  No
# 216               Zimbabwe  ...                  No
#
# [217 rows x 16 columns]>

# %%
df["Region"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'Americas'], dtype=object)

# %% [markdown]
# Since there are 6 unique regions we can decide our dashboard into these six regions and analyze those values

# %%
import missingno as msn
msn.bar(df)

# %% [markdown]
# As we have already decided that we will use the region to divide the data we will drop any null value of region

# %%
df = df.dropna(subset=['Region'])
msn.bar(df)

# %%
df.columns
# Out:
# Index(['Country Name', 'Region', 'Subregion', 'Intermediate Region', 'GNI',
#        'Internet use', 'International tourism', 'Life expectancy, female',
#        'Life expectancy, male', 'Physicians', 'Population',
#        'Women in national parliament', 'Tertiary education, female',
#        'Tertiary education, male', 'Greenhouse gas emissions',
#        'High Income Economy'],
#       dtype='object')

# %%
df["High Income Economy"]
df_line = df.sort_values(by=["High Income Economy"], ascending=True)
df_line
# Out:
#               Country Name  ... High Income Economy
# 0              Afghanistan  ...                  No
# 126              Mauritius  ...                  No
# 127                 Mexico  ...                  No
# 128  Micronesia, Fed. Sts.  ...                  No
# 129                Moldova  ...                  No
# ..                     ...  ...                 ...
# 117       Macao SAR, China  ...                 Yes
# 159                  Qatar  ...                 Yes
# 158            Puerto Rico  ...                 Yes
# 156                 Poland  ...                 Yes
# 87                 Hungary  ...                 Yes
#
# [216 rows x 16 columns]

# %% [markdown]
# We can plot a graph depicting all the high econmy and low economy countries of all the 6 regions

# %% [markdown]
# Plot the heatmap to see correlation between various columns

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

covar_mat=df.corr()
sns.heatmap(covar_mat)
plt.show()
